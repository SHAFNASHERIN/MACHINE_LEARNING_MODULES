# %%
#pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
#pandas series

# %%
df = pd.Series([1.0,3.0,5.0,6.0,7.0,9.0,11.0,13.0])

# %%
df
# Out:
# 0     1.0
# 1     3.0
# 2     5.0
# 3     6.0
# 4     7.0
# 5     9.0
# 6    11.0
# 7    13.0
# dtype: float64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (8,)

# %%
df.head()  #default head n is 5
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    6.0
# 4    7.0
# dtype: float64

# %%
df.tail() #default tail n is 5
# Out:
# 3     6.0
# 4     7.0
# 5     9.0
# 6    11.0
# 7    13.0
# dtype: float64

# %%
#Pandas data frame - Using Numpy Dataset
data=(np.arange(0,20).reshape(4,5))
df = pd.DataFrame(data,index=['Row1','Row2','Row3','Row4'],columns=["column1","column2","column3","column4","column5"])

# %%
df
# Out:
#       column1  column2  column3  column4  column5
# Row1        0        1        2        3        4
# Row2        5        6        7        8        9
# Row3       10       11       12       13       14
# Row4       15       16       17       18       19

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#       column1  column2  column3  column4  column5
# Row1        0        1        2        3        4
# Row2        5        6        7        8        9

# %%
df.tail(2)
# Out:
#       column1  column2  column3  column4  column5
# Row3       10       11       12       13       14
# Row4       15       16       17       18       19

# %%
df.loc['Row1']
# Out:
# column1    0
# column2    1
# column3    2
# column4    3
# column5    4
# Name: Row1, dtype: int64

# %%
type(df.loc['Row1'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[1:,1:]
# Out:
#       column2  column3  column4  column5
# Row2        6        7        8        9
# Row3       11       12       13       14
# Row4       16       17       18       19

# %%
df.loc[['Row1','Row2']]
# Out:
#       column1  column2  column3  column4  column5
# Row1        0        1        2        3        4
# Row2        5        6        7        8        9

# %%
df['column2']
# Out:
# Row1     1
# Row2     6
# Row3    11
# Row4    16
# Name: column2, dtype: int64

# %%
type(df['column2'])
# Out:
# pandas.core.series.Series

# %%
df[['column2','column3']]
# Out:
#       column2  column3
# Row1        1        2
# Row2        6        7
# Row3       11       12
# Row4       16       17

# %%
df
# Out:
#       column1  column2  column3  column4  column5
# Row1        0        1        2        3        4
# Row2        5        6        7        8        9
# Row3       10       11       12       13       14
# Row4       15       16       17       18       19

# %%
#Pandas DataFrame - using Dict
data={
    "calories":[420,300,390],
    "Duration":[50,40,45]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    calories  Duration
# 0       420        50
# 1       300        40
# 2       390        45

# %%
df.loc[1]
# Out:
# calories    300
# Duration     40
# Name: 1, dtype: int64

# %%
# Pandas DataFrame - using csv

df = pd.read_csv("datas/supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
df['Branch']
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# ...

# %%
df.tail(6)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%    Total  \
# 994  Electronic accessories       60.95         1   3.0475  63.9975
# 995       Health and beauty       40.35         1   2.0175  42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.49
# 997      Food and beverages       31.84         1   1.5920   33.432
# 998      Home and lifestyle       65.82         1   3.2910   69.111
# 999     Fashion accessories       88.34         7  30.9190  649.299
#
#            Date   Time  Payment    cogs  gross margin percentage  \
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.size
# Out:
# 17000

# %%
df.describe() #only shows numerical features
# Out:
#         Unit price     Quantity       Tax 5%        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   307.58738
# std      26.494628     2.923431    11.708825   234.17651
# min      10.080000     1.000000     0.508500    10.17000
# 25%      32.875000     3.000000     5.924875   118.49750
# 50%      55.230000     5.000000    12.088000   241.76000
# 75%      77.935000     8.000000    22.445250   448.90500
# max      99.960000    10.000000    49.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# ...

# %%
df.describe(include='O') #objects are describe
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#           Total        Date   Time  Payment
# count      1000        1000   1000     1000
# unique      990          89    506        3
# top     216.846  02-07-2019  19:48  Ewallet
# freq          2          20      7      345

# %%
df.describe(include='all')#categorical feature and numerical feature
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
#missing value info
df.isna().sum()
#there is no missing values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df1 = pd.read_csv(r"datas/abcd.csv")  #relativepath

# %%
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0            NaN      A     Yangon        Member  Female
# 1            NaN      C  Naypyitaw        Normal  Female
# 2    631-41-3108    NaN     Yangon        Normal    Male
# 3    123-19-1176    NaN     Yangon        Member    Male
# 4    373-73-7910      A        NaN        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
df1[['Branch','Gender']]
# Out:
#     Branch  Gender
# 0        A  Female
# 1        C  Female
# 2      NaN    Male
# 3      NaN    Male
# 4        A    Male
# ..     ...     ...
# 995      C    Male
# 996      B  Female
# 997      A    Male
# 998      A    Male
# 999      A  Female
#
# [1000 rows x 2 columns]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0          NaN      A     Yangon        Member  Female
# 1          NaN      C  Naypyitaw        Normal  Female
# 2  631-41-3108    NaN     Yangon        Normal    Male
# 3  123-19-1176    NaN     Yangon        Member    Male
# 4  373-73-7910      A        NaN        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# 4       Sports and travel         NaN         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
df1.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%    Total        Date   Time  Payment  \
# 995       40.35         1   2.0175  42.3675   1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.49  03-02-2019  17:16  Ewallet
# 997       31.84         1   1.5920   33.432  02-09-2019  13:22     Cash
# 998       65.82         1   3.2910   69.111   2/22/2019  15:33     Cash
# 999       88.34         7  30.9190  649.299   2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
df1.describe()
# Out:
#        Unit price     Quantity       Tax 5%        cogs  \
# count  998.000000  1000.000000  1000.000000  1000.00000
# mean    55.611653     5.510000    15.379369   307.58738
# std     26.486648     2.923431    11.708825   234.17651
# min     10.080000     1.000000     0.508500    10.17000
# 25%     32.825000     3.000000     5.924875   118.49750
# 50%     55.055000     5.000000    12.088000   241.76000
# 75%     77.710000     8.000000    22.445250   448.90500
# max     99.960000    10.000000    49.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# ...

# %%
df1.size
# Out:
# 17000

# %%
df1.shape
# Out:
# (1000, 17)

# %%
df1.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df1.describe(include='O')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count           998    998     998           999     999                 1000
# unique          998      3       3             2       2                    6
# top     631-41-3108      A  Yangon        Member  Female  Fashion accessories
# freq              1    338     339           501     501                  178
#
#           Total        Date   Time  Payment
# count      1000         999    999     1000
# unique      990          89    505        3
# top     216.846  02-07-2019  19:48  Ewallet
# freq          2          20      7      345

# %%
df1.describe(include='all')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count           998    998     998           999     999                 1000
# unique          998      3       3             2       2                    6
# top     631-41-3108      A  Yangon        Member  Female  Fashion accessories
# freq              1    338     339           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
df1.isna().sum()
# Out:
# Invoice ID                 2
# Branch                     2
# City                       2
# Customer type              1
# Gender                     1
# Product line               0
# Unit price                 2
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       1
# Time                       1
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#for deleting rows and columns we use 'drop'


#we have to specify the axis
#Axis=0 for rows
#Axis=1 for columns
updateddf2 = df1.drop('Invoice ID',axis=1)

# %%
updateddf2
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2      NaN     Yangon        Normal    Male      Home and lifestyle
# 3      NaN     Yangon        Member    Male       Health and beauty
# 4        A        NaN        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...

# %%
del updateddf2['Branch']

# %%
updateddf2
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4          NaN        Normal    Male       Sports and travel         NaN
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%     Total        Date   Time      Payment    cogs  \
# ...

# %%
df = pd.read_json("datas/data.json")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df = pd.read_csv('datas/dirtydata.csv')
print("DataFrame :\n",df)
# Out:
# DataFrame :
#      Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#prints information about Dataframe  information contains 
#no.of columns,column labels,column datatypes,memory usage,range index,and
# the number of cells in each column 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
new_df = df.dropna()
print(new_df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...
